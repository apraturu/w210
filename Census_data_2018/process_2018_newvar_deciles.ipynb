# %% [markdown]
# # Process 2018 Data to Match 1994
# #### 9/26/2020
# ---

# %% [markdown]
# ## Load and Process Dataset
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the Data Set
df_2018 = pd.read_csv("2018_new-var_mapped_processed.csv")
df_2018.head()
# Out:
#   Geographic-division  area-code     region state RT  person-weight  age  \
# 0         New England        704  Northeast    MA  P             88   48
# 1         New England        704  Northeast    MA  P             78   47
# 2      South Atlantic       1101      South    FL  P             51   50
# 3  West North Central       1301    Midwest    MN  P             34   19
# 4  East North Central       1100    Midwest    MI  P            107   24
#
#                               citizenship-status  class-worker  \
# 0  Born-PR-Guam-USvirginislands-northernmarianas     State-gov
# 1                                        Born-US  Private-prof
# 2                                        Born-US  Private-prof
# 3                                        Born-US  Private-prof
# 4                                        Born-US  Private-prof
#
#             education  ...                                         occupation  \
# ...

# %%
df_2018['income_adjusted'] = pd.qcut(df_2018['income'], 10, labels=False)

# df_2018.loc[df_2018['income'] < 1000, 'income_adjusted'] = '< $1,000'
# df_2018.loc[(df_2018['income'] >= 1000) & (df_2018['income'] < 25000), 'income_adjusted'] = '\$1,000-$24,999'
# df_2018.loc[(df_2018['income'] >= 25000) & (df_2018['income'] < 50000), 'income_adjusted'] = '\$25,000-$49,999'
# df_2018.loc[(df_2018['income'] >= 50000) & (df_2018['income'] < 75000), 'income_adjusted'] = '\$50,000-$74,999'
# df_2018.loc[(df_2018['income'] >= 75000) & (df_2018['income'] < 100000), 'income_adjusted'] = '\$75,000-$99,999'
# df_2018.loc[(df_2018['income'] >= 100000) & (df_2018['income'] < 125000), 'income_adjusted'] = '\$100,000-$124,999'
# df_2018.loc[(df_2018['income'] >= 125000) & (df_2018['income'] < 150000), 'income_adjusted'] = '\$125,000-$149,999'
# df_2018.loc[(df_2018['income'] >= 150000) & (df_2018['income'] < 175000), 'income_adjusted'] = '\$150,000-$174,999'
# df_2018.loc[(df_2018['income'] >= 175000) & (df_2018['income'] < 200000), 'income_adjusted'] = '\$175,000-$199,999'
# df_2018.loc[(df_2018['income'] >= 200000) & (df_2018['income'] < 250000), 'income_adjusted'] = '\$200,000-$249,999'
# df_2018.loc[df_2018['income'] >= 250000, 'income_adjusted'] = '$250,000+'

# df_2018['income_adjusted'].value_counts()

df_2018 = df_2018.drop(columns=['income']).rename(columns={'income_adjusted': 'income'})

df_2018.head()
# Out:
#   Geographic-division  area-code     region state RT  person-weight  age  \
# 0         New England        704  Northeast    MA  P             88   48
# 1         New England        704  Northeast    MA  P             78   47
# 2      South Atlantic       1101      South    FL  P             51   50
# 3  West North Central       1301    Midwest    MN  P             34   19
# 4  East North Central       1100    Midwest    MI  P            107   24
#
#                               citizenship-status  class-worker  \
# 0  Born-PR-Guam-USvirginislands-northernmarianas     State-gov
# 1                                        Born-US  Private-prof
# 2                                        Born-US  Private-prof
# 3                                        Born-US  Private-prof
# 4                                        Born-US  Private-prof
#
#             education  ...                                         occupation  \
# ...

# %%
df_2018.groupby('income').count()
# Out:
#         Geographic-division  area-code  region  state     RT  person-weight  \
# income
# 0                     85722      85722   85722  85722  85722          85722
# 1                     85226      85226   85226  85226  85226          85226
# 2                     83393      83393   83393  83393  83393          83393
# 3                     90041      90041   90041  90041  90041          90041
# 4                     79196      79196   79196  79196  79196          79196
# 5                     84852      84852   84852  84852  84852          84852
# 6                     86691      86691   86691  86691  86691          86691
# 7                     89614      89614   89614  89614  89614          89614
# 8                     77782      77782   77782  77782  77782          77782
# 9                     84634      84634   84634  84634  84634          84634
#
#           age  citizenship-status  class-worker  education  marital-status  \
# income
# ...

# %%
df_2018.to_csv('2018_newvar_decile.csv',index=False)
