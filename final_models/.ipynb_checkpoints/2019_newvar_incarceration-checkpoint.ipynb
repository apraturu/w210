# %% [markdown]
# # Run Models on 2019 Data Joined with Incarceration Rates
# #### 10/23/2020
# ---

# %% [markdown]
# ## Load and Process Dataset
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import wandb
import warnings
warnings.filterwarnings('ignore')

# %%
wandb.init(project="2019_newvar_incarceration")
# Out:
# wandb: Currently logged in as: apraturu (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.8<br/>
#                 Syncing run <strong style="color:#cdcd00">fearless-shadow-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/apraturu/2019_newvar_incarceration" target="_blank">https://wandb.ai/apraturu/2019_newvar_incarceration</a><br/>
#                 Run page: <a href="https://wandb.ai/apraturu/2019_newvar_incarceration/runs/3j80p049" target="_blank">https://wandb.ai/apraturu/2019_newvar_incarceration/runs/3j80p049</a><br/>
#                 Run data is saved locally in <code>wandb/run-20201025_151820-3j80p049</code><br/><br/>
# <h1>Run(3j80p049)</h1><p></p><iframe src="https://wandb.ai/apraturu/2019_newvar_incarceration/runs/3j80p049" style="border:none;width:100%;height:400px"></iframe>

# %% [markdown]
# ### Read in `adult.csv` data

# %%
df = pd.read_csv('../final_data/2019_new-var_inc.csv').sample(frac=1)
df.head()
# Out:
#         Geographic-division  area-code     region state RT  person-weight  \
# 1261943     Middle Atlantic       2500  Northeast    PA  P            138
# 1255857     Middle Atlantic       2801  Northeast    PA  P             38
# 1630800      South Atlantic        700      South    WV  P             40
# 584673   East North Central       2302    Midwest    IN  P             43
# 548597   East North Central        202    Midwest    IL  P             82
#
#          age citizenship-status  class-worker  education  ...  \
# 1261943   29            Born-US  Private-prof     grade9  ...
# 1255857   41            Born-US  Private-prof     HSgrad  ...
# 1630800   46            Born-US     Local-gov     master  ...
# 584673    28            Born-US  Private-prof   bachelor  ...
# 548597    43            Born-US  Private-prof  associate  ...
#
#         Incarceration rate per 100000 Incarceration rate: White alone  \
# 1261943                    770.091965                      398.086234
# 1255857                    770.091965                      398.086234
# 1630800                    895.361777                      644.889505
# 584673                     751.009978                      563.579549
# 548597                     552.022691                      283.017521
#
#          Incarceration rate: Black or African American alone  \
# 1261943                                        3268.517060
# 1255857                                        3268.517060
# 1630800                                        7360.116596
# 584673                                         2814.353133
# 548597                                         2128.252360
#
#         Incarceration rate: American Indian and Alaska Native alone  \
# 1261943                                        1031.926387
# 1255857                                        1031.926387
# 1630800                                        2561.394243
# 584673                                          888.311126
# 548597                                          821.145054
#
#         Incarceration rate: Asian alone  \
# 1261943                      152.110643
# 1255857                      152.110643
# 1630800                      378.848944
# 584673                        75.141011
# 548597                        42.594227
#
#          Incarceration rate: Native Hawaiian and other Pacific Islander alone  \
# 1261943                                         629.619491
# 1255857                                         629.619491
# 1630800                                        3271.028037
# 584673                                          553.662692
# 548597                                          345.679012
#
#          Incarceration rate: Some other race alone  \
# 1261943                                3194.532582
# 1255857                                3194.532582
# 1630800                                6357.247916
# 584673                                  434.471537
# 548597                                  472.828333
#
#         Incarceration rate: Two or more races  \
# 1261943                            385.981878
# 1255857                            385.981878
# 1630800                            652.125857
# 584673                             177.481020
# 548597                             149.319613
#
#         Incarceration rate: Hispanic or Latino  \
# 1261943                            2000.805936
# 1255857                            2000.805936
# 1630800                            4585.054787
# 584673                              781.356250
# 548597                              472.090346
#
#          Incarceration rate: White alone, not Hispanic or Latino
# 1261943                                         374.554764
# 1255857                                         374.554764
# 1630800                                         621.634335
# 584673                                          542.121532
# 548597                                          258.014658
#
# [5 rows x 31 columns]

# %%
df.loc[df['income'] <= 50000, 'income_adjusted'] = '<=50K'
df.loc[df['income'] > 50000, 'income_adjusted'] = '>50K' 

df = df.drop(columns=['income']).rename(columns={'income_adjusted': 'income'})#.dropna()

df['field-of-degree'] = df['field-of-degree'].fillna('Unknown')
df['stem-degree'] = df['stem-degree'].fillna('Unknown')

df = df.dropna()

df.head()
# Out:
#         Geographic-division  area-code     region state RT  person-weight  \
# 1261943     Middle Atlantic       2500  Northeast    PA  P            138
# 1255857     Middle Atlantic       2801  Northeast    PA  P             38
# 1630800      South Atlantic        700      South    WV  P             40
# 584673   East North Central       2302    Midwest    IN  P             43
# 548597   East North Central        202    Midwest    IL  P             82
#
#          age citizenship-status  class-worker  education  ...  \
# 1261943   29            Born-US  Private-prof     grade9  ...
# 1255857   41            Born-US  Private-prof     HSgrad  ...
# 1630800   46            Born-US     Local-gov     master  ...
# 584673    28            Born-US  Private-prof   bachelor  ...
# 548597    43            Born-US  Private-prof  associate  ...
#
#         Incarceration rate: White alone  \
# 1261943                      398.086234
# 1255857                      398.086234
# 1630800                      644.889505
# 584673                       563.579549
# 548597                       283.017521
#
#         Incarceration rate: Black or African American alone  \
# 1261943                                        3268.517060
# 1255857                                        3268.517060
# 1630800                                        7360.116596
# 584673                                         2814.353133
# 548597                                         2128.252360
#
#          Incarceration rate: American Indian and Alaska Native alone  \
# 1261943                                        1031.926387
# 1255857                                        1031.926387
# 1630800                                        2561.394243
# 584673                                          888.311126
# 548597                                          821.145054
#
#         Incarceration rate: Asian alone  \
# 1261943                      152.110643
# 1255857                      152.110643
# 1630800                      378.848944
# 584673                        75.141011
# 548597                        42.594227
#
#         Incarceration rate: Native Hawaiian and other Pacific Islander alone  \
# 1261943                                         629.619491
# 1255857                                         629.619491
# 1630800                                        3271.028037
# 584673                                          553.662692
# 548597                                          345.679012
#
#          Incarceration rate: Some other race alone  \
# 1261943                                3194.532582
# 1255857                                3194.532582
# 1630800                                6357.247916
# 584673                                  434.471537
# 548597                                  472.828333
#
#          Incarceration rate: Two or more races  \
# 1261943                             385.981878
# 1255857                             385.981878
# 1630800                             652.125857
# 584673                              177.481020
# 548597                              149.319613
#
#         Incarceration rate: Hispanic or Latino  \
# 1261943                            2000.805936
# 1255857                            2000.805936
# 1630800                            4585.054787
# 584673                              781.356250
# 548597                              472.090346
#
#         Incarceration rate: White alone, not Hispanic or Latino income
# 1261943                                         374.554764       <=50K
# 1255857                                         374.554764        >50K
# 1630800                                         621.634335       <=50K
# 584673                                          542.121532       <=50K
# 548597                                          258.014658       <=50K
#
# [5 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Geographic-division                                                     0
# area-code                                                               0
# region                                                                  0
# state                                                                   0
# RT                                                                      0
# person-weight                                                           0
# age                                                                     0
# citizenship-status                                                      0
# class-worker                                                            0
# education                                                               0
# marital-status                                                          0
# occupation                                                              0
# relationship                                                            0
# race                                                                    0
# sex                                                                     0
# extra-income                                                            0
# hours-per-week                                                          0
# field-of-degree                                                         0
# place-of-birth                                                          0
# stem-degree                                                             0
# Incarceration rate per 100000                                           0
# Incarceration rate: White alone                                         0
# Incarceration rate: Black or African American alone                     0
# Incarceration rate: American Indian and Alaska Native alone             0
# Incarceration rate: Asian alone                                         0
# Incarceration rate: Native Hawaiian and other Pacific Islander alone    0
# Incarceration rate: Some other race alone                               0
# Incarceration rate: Two or more races                                   0
# Incarceration rate: Hispanic or Latino                                  0
# Incarceration rate: White alone, not Hispanic or Latino                 0
# income                                                                  0
# dtype: int64

# %%
X = df.drop(columns=['income'], axis = 1)
y = df[['income']].to_numpy()

# %%
labels = np.unique(y)
features = list(X.columns)

# %%
X.columns
# Out:
# Index(['Geographic-division', 'area-code', 'region', 'state', 'RT',
#        'person-weight', 'age', 'citizenship-status', 'class-worker',
#        'education', 'marital-status', 'occupation', 'relationship', 'race',
#        'sex', 'extra-income', 'hours-per-week', 'field-of-degree',
#        'place-of-birth', 'stem-degree', 'Incarceration rate per 100000',
#        'Incarceration rate: White alone',
#        'Incarceration rate: Black or African American alone',
#        'Incarceration rate: American Indian and Alaska Native alone',
#        'Incarceration rate: Asian alone',
#        'Incarceration rate: Native Hawaiian and other Pacific Islander alone',
#        'Incarceration rate: Some other race alone',
#        'Incarceration rate: Two or more races',
#        'Incarceration rate: Hispanic or Latino',
#        'Incarceration rate: White alone, not Hispanic or Latino'],
#       dtype='object')

# %% [markdown]
# ### Pre-process categorical variables

# %%
cat_var = ['Geographic-division', 'area-code', 'region', 'state', 'RT', 'citizenship-status', 'class-worker', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'field-of-degree', 'place-of-birth', 'stem-degree']
for f in cat_var:
    enc = preprocessing.LabelEncoder()
    X[f] = enc.fit_transform(X[f])

scaler = preprocessing.StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)

# %% [markdown]
# ### Split data into test and training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(X_test)
# Out:
# 334460

# %% [markdown]
# ## Train Models and Establish Baseline Scores

# %% [markdown]
# ### Logistic Regression

# %%
# Train model, get predictions
model = LogisticRegression()
model.fit(X, y)
y_pred = model.predict(X_test)
y_probas = model.predict_proba(X_test)
importances = model.coef_
indices = np.argsort(importances)[::-1]

# %%
print(X_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1337840 entries, 1442516 to 1397067
# Data columns (total 30 columns):
#  #   Column                                                                Non-Null Count    Dtype
# ---  ------                                                                --------------    -----
#  0   Geographic-division                                                   1337840 non-null  float64
#  1   area-code                                                             1337840 non-null  float64
#  2   region                                                                1337840 non-null  float64
#  3   state                                                                 1337840 non-null  float64
#  4   RT                                                                    1337840 non-null  float64
#  5   person-weight                                                         1337840 non-null  float64
#  6   age                                                                   1337840 non-null  float64
#  7   citizenship-status                                                    1337840 non-null  float64
#  8   class-worker                                                          1337840 non-null  float64
#  9   education                                                             1337840 non-null  float64
#  10  marital-status                                                        1337840 non-null  float64
#  11  occupation                                                            1337840 non-null  float64
#  12  relationship                                                          1337840 non-null  float64
#  13  race                                                                  1337840 non-null  float64
#  14  sex                                                                   1337840 non-null  float64
#  15  extra-income                                                          1337840 non-null  float64
#  16  hours-per-week                                                        1337840 non-null  float64
#  17  field-of-degree                                                       1337840 non-null  float64
#  18  place-of-birth                                                        1337840 non-null  float64
#  19  stem-degree                                                           1337840 non-null  float64
#  20  Incarceration rate per 100000                                         1337840 non-null  float64
#  21  Incarceration rate: White alone                                       1337840 non-null  float64
#  22  Incarceration rate: Black or African American alone                   1337840 non-null  float64
#  23  Incarceration rate: American Indian and Alaska Native alone           1337840 non-null  float64
#  24  Incarceration rate: Asian alone                                       1337840 non-null  float64
#  25  Incarceration rate: Native Hawaiian and other Pacific Islander alone  1337840 non-null  float64
#  26  Incarceration rate: Some other race alone                             1337840 non-null  float64
#  27  Incarceration rate: Two or more races                                 1337840 non-null  float64
#  28  Incarceration rate: Hispanic or Latino                                1337840 non-null  float64
#  29  Incarceration rate: White alone, not Hispanic or Latino               1337840 non-null  float64
# dtypes: float64(30)
# memory usage: 316.4 MB
# None

# %%
# Visualize model performance
wandb.sklearn.plot_classifier(
    model, X_train, X_test, y_train, y_test, y_pred, y_probas, labels,
    is_binary=True, model_name='LogisticRegression', feature_names=features)
# Out:
# wandb:
# wandb: Plotting LogisticRegression.
# wandb: Logged feature importances.
# wandb: Logged learning curve.
# wandb: Logged confusion matrix.
# wandb: Logged summary metrics.
# wandb: Logged class proportions.
# wandb: Logged calibration curve.
# wandb: WARNING wandb uses only the first 10000 datapoints to create the plots.
# wandb: WARNING wandb uses only the first 10000 datapoints to create the plots.
# WARNING:root:Truncating wandb.Table object to 10000 rows.
# wandb: Logged roc curve.
# wandb: Logged precision recall curve.

# %%
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.77      0.84      0.81    201617
#         >50K       0.72      0.63      0.67    132843
#
#     accuracy                           0.76    334460
#    macro avg       0.75      0.73      0.74    334460
# weighted avg       0.75      0.76      0.75    334460
