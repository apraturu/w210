# %% [markdown]
# ## Creating 2019 dataset - with extra columns and variables not included in 1994
# #### 10/2/2020

# %% [markdown]
# ## Load in data
#
# #### import libraries and packages

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
#from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Read in the data - both 'a' and 'b' csv files - be careful running these cells - data is 1 GB

# %%
df_1 = pd.read_csv('Census_data/2019-1-year-raw/psam_pusa.csv')
df_1.shape
# Out:
# (1658808, 288)

# %%
# df_2 = pd.read_csv('Census_data/2019-1-year-raw/psam_pusb.csv')
df_2.shape
# Out:
# (1580745, 288)

# %%
df_2019 = pd.concat([df_1, df_2], axis=0)
df_2019.head()
# Out:
#   RT       SERIALNO  DIVISION  SPORDER  PUMA  REGION  ST   ADJINC  PWGTP  \
# 0  P  2019GQ0000088         6        1  2200       3   1  1010145     11
# 1  P  2019GQ0000096         6        1  1000       3   1  1010145     70
# 2  P  2019GQ0000153         6        1  1100       3   1  1010145     20
# 3  P  2019GQ0000198         6        1  1100       3   1  1010145     79
# 4  P  2019GQ0000205         6        1  2701       3   1  1010145     53
#
#    AGEP  ...  PWGTP71  PWGTP72  PWGTP73  PWGTP74  PWGTP75  PWGTP76  PWGTP77  \
# 0    39  ...       22       10       20       13       10       21       12
# 1    21  ...       67      131       11       10       73       71      128
# 2    19  ...       20       19        1       43       23       22        1
# 3    77  ...      156       83       79       76        5       80      159
# 4    41  ...        8       96       54       98      104       52       53
#
#    PWGTP78  PWGTP79  PWGTP80
# 0       22        0       10
# ...

# %%
df_2019.shape
# Out:
# (3239553, 288)

# %%
#keep only columns of interest
#includes columns from original 1994 data, plus some new variables
df_2019 = df_2019[['DIVISION','PUMA','REGION','ST','RT','PWGTP',
              'AGEP','CIT','COW','SCHL','MAR','OCCP','RELSHIPP','RAC1P','SEX','INTP',
              'WKHP','FOD1P','FOD2P','POBP','PINCP','SCIENGP']]
df_2019.head()
# Out:
#    DIVISION  PUMA  REGION  ST RT  PWGTP  AGEP  CIT  COW  SCHL  ...  RELSHIPP  \
# 0         6  2200       3   1  P     11    39    1  NaN  13.0  ...        38
# 1         6  1000       3   1  P     70    21    1  NaN  13.0  ...        37
# 2         6  1100       3   1  P     20    19    1  2.0  19.0  ...        38
# 3         6  1100       3   1  P     79    77    1  NaN  12.0  ...        37
# 4         6  2701       3   1  P     53    41    1  NaN  12.0  ...        37
#
#    RAC1P  SEX  INTP  WKHP  FOD1P  FOD2P  POBP    PINCP  SCIENGP
# 0      2    1   0.0   NaN    NaN    NaN     1   9000.0      NaN
# 1      1    2   0.0   NaN    NaN    NaN    13    150.0      NaN
# 2      2    1   0.0  32.0    NaN    NaN     1   1400.0      NaN
# 3      1    1   0.0   NaN    NaN    NaN     1  22700.0      NaN
# 4      2    1   0.0   NaN    NaN    NaN     1      0.0      NaN
#
# [5 rows x 22 columns]

# %%
df_2019.shape
# Out:
# (3239553, 22)

# %%
#filter data to only include people over 16, with income over 100, and who work more than 0 hours per week
df_2019 = df_2019[(df_2019['AGEP']> 16) & (df_2019['PINCP']>100) & (df_2019['WKHP']>0)]
df_2019.head()
# Out:
#     DIVISION  PUMA  REGION  ST RT  PWGTP  AGEP  CIT  COW  SCHL  ...  RELSHIPP  \
# 2          6  1100       3   1  P     20    19    1  2.0  19.0  ...        38
# 8          6  2100       3   1  P     61    39    1  4.0  21.0  ...        37
# 11         6   301       3   1  P     89    19    1  1.0  19.0  ...        38
# 13         6  2100       3   1  P     61    39    1  4.0  21.0  ...        37
# 14         6  2000       3   1  P     49    21    1  1.0  19.0  ...        38
#
#     RAC1P  SEX  INTP  WKHP   FOD1P  FOD2P  POBP    PINCP  SCIENGP
# 2       2    1   0.0  32.0     NaN    NaN     1   1400.0      NaN
# 8       1    2   0.0  40.0  3301.0    NaN     1  60000.0      2.0
# 11      2    1   0.0  31.0     NaN    NaN     1    390.0      NaN
# 13      1    2   0.0  40.0  3301.0    NaN     1  60000.0      2.0
# 14      1    1   0.0  12.0     NaN    NaN    36   4440.0      NaN
#
# [5 rows x 22 columns]

# %%
df_2019.shape
# Out:
# (1672300, 22)

# %%
# create csv

df_2019.to_csv('2019_new-var_mapped.csv',index=False)
