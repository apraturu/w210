# %% [markdown]
# # Joining the 2018 data (with new variables) to incarceration rates by state

# %%
import pandas as pd
import numpy as np

# %%
# !pwd
# Out:
# /Users/alexandrawest/Desktop/W210-Capstone/joins

# %%
df_2018 = pd.read_csv("/Users/alexandrawest/Desktop/W210-Capstone/new-var-2018/2018_new-var_mapped_processed.csv")
df_2018.head()
# Out:
#   Geographic-division  area-code     region state RT  person-weight  age  \
# 0         New England        704  Northeast    MA  P             88   48
# 1         New England        704  Northeast    MA  P             78   47
# 2      South Atlantic       1101      South    FL  P             51   50
# 3  West North Central       1301    Midwest    MN  P             34   19
# 4  East North Central       1100    Midwest    MI  P            107   24
#
#                               citizenship-status  class-worker  \
# 0  Born-PR-Guam-USvirginislands-northernmarianas     State-gov
# 1                                        Born-US  Private-prof
# 2                                        Born-US  Private-prof
# 3                                        Born-US  Private-prof
# 4                                        Born-US  Private-prof
#
#             education  ...                                         occupation  \
# ...

# %%
df_inc = pd.read_csv("incarceration_rates_2010.csv")
df_inc.head()
# Out:
#   State  Incarceration rate per 100000  Incarceration rate: White alone  \
# 0    AL                     861.491095                       552.208375
# 1    AK                     592.201692                       382.620741
# 2    AZ                    1060.181786                       774.781712
# 3    AR                     886.307503                       616.596347
# 4    CA                     689.341556                       605.996084
#
#    Incarceration rate: Black or African American alone  \
# 0                                        1788.284447
# 1                                        1293.900185
# 2                                        3183.685446
# 3                                        2432.345325
# 4                                        3036.268547
#
#    Incarceration rate: American Indian and Alaska Native alone  \
# 0                                         283.506981
# 1                                        1505.659334
# ...

# %%
# make a copy of df_2018 that we will join to

df_2018_inc = df_2018.copy()
df_2018_inc.head()
# Out:
#   Geographic-division  area-code     region state RT  person-weight  age  \
# 0         New England        704  Northeast    MA  P             88   48
# 1         New England        704  Northeast    MA  P             78   47
# 2      South Atlantic       1101      South    FL  P             51   50
# 3  West North Central       1301    Midwest    MN  P             34   19
# 4  East North Central       1100    Midwest    MI  P            107   24
#
#                               citizenship-status  class-worker  \
# 0  Born-PR-Guam-USvirginislands-northernmarianas     State-gov
# 1                                        Born-US  Private-prof
# 2                                        Born-US  Private-prof
# 3                                        Born-US  Private-prof
# 4                                        Born-US  Private-prof
#
#             education  ...                                         occupation  \
# ...

# %%
# try a join

df_2018_inc = df_2018_inc.join(df_inc.set_index('State'), on='state')
df_2018_inc.head()
# Out:
#   Geographic-division  area-code     region state RT  person-weight  age  \
# 0         New England        704  Northeast    MA  P             88   48
# 1         New England        704  Northeast    MA  P             78   47
# 2      South Atlantic       1101      South    FL  P             51   50
# 3  West North Central       1301    Midwest    MN  P             34   19
# 4  East North Central       1100    Midwest    MI  P            107   24
#
#                               citizenship-status  class-worker  \
# 0  Born-PR-Guam-USvirginislands-northernmarianas     State-gov
# 1                                        Born-US  Private-prof
# 2                                        Born-US  Private-prof
# 3                                        Born-US  Private-prof
# 4                                        Born-US  Private-prof
#
#             education  ... Incarceration rate per 100000  \
# 0                 GED  ...                    376.976154
# ...

# %%
# create new csv of processed data
# this creates a csv that is ~150 MB - too big for Git
df_2018_inc.to_csv('2018_new-var_inc.csv',index=False)
